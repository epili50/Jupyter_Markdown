# %% [markdown]
# # Mi primer ejercicio el Jupyter

# %% [markdown]
# ## calculos

# %%
2 + 2
# Out:
# 4

# %%
print(10 > 9)
x = 15 + 10
print (bool(x == 20))
# Out:
# True
# False

# %%
x = 4
if x % 2 == 0:
    print("Es par")
# Out:
# Es par

# %% [markdown]
# ## Lista:
#
# * primero
# * segundo
# * tercer

# %% [markdown]
# ![IT%20logo.png](attachment:IT%20logo.png)

# %% [markdown]
# _[Link to IT Barcelona Activa](https://itacademy.barcelonactiva.cat/login/index.php)_

# %% [markdown]
# ### Estilos de letra:
# <b> blank </b>
# *cursiva*
